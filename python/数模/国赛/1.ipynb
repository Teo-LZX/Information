# %% [markdown]
# # 这是问题四的相关性分析

# %%
import numpy as np
import pandas as pd
from scipy.stats import pearsonr
data = np.array(pd.read_csv('./data.csv'))
data[0]
# Out:
# array([69.33, 0.0, 9.99, 6.32, 0.87, 3.93, 1.74, 3.87, 0.0, 0.0, 1.17,
#        0.0, 0.0, 0.39, 'C', '高钾', '蓝绿', '未风化'], dtype=object)

# %% [markdown]
# ## 先读取、处理数据

# %%
print(len(data))

data高钾 = []
data铅钡 = []

for it in data:
    if it[-3] == '高钾':
        data高钾.append(it)
    elif it[-3] == '铅钡':
        data铅钡.append(it)

print(len(data高钾))
print(len(data铅钡))

df = pd.DataFrame(data高钾, columns=['二氧化硅(SiO2)','氧化钠(Na2O)','氧化钾(K2O)','氧化钙(CaO)','氧化镁(MgO)','氧化铝(Al2O3)','氧化铁(Fe2O3)','氧化铜(CuO)','氧化铅(PbO)','氧化钡(BaO)','五氧化二磷(P2O5)','氧化锶(SrO)','氧化锡(SnO2)','二氧化硫(SO2)','纹饰','类型','颜色','风化'])
df.to_csv('./data高钾.csv', index=False)
df = pd.DataFrame(data铅钡, columns=['二氧化硅(SiO2)','氧化钠(Na2O)','氧化钾(K2O)','氧化钙(CaO)','氧化镁(MgO)','氧化铝(Al2O3)','氧化铁(Fe2O3)','氧化铜(CuO)','氧化铅(PbO)','氧化钡(BaO)','五氧化二磷(P2O5)','氧化锶(SrO)','氧化锡(SnO2)','二氧化硫(SO2)','纹饰','类型','颜色','风化'])
df.to_csv('./data铅钡.csv', index=False)

# %%
高钾数据 = pd.read_excel('./高钾玻璃化学成分的相关性分析.xlsx')
铅钡数据 = pd.read_excel('./铅钡玻璃化学成分的相关性分析.xlsx')
高钾数据
# Out:
#      Unnamed: 0       二氧化硅(SiO2)        氧化钠(Na2O)         氧化铜(CuO)   \
# 0    二氧化硅(SiO2)   1.000(0.000***)  -0.475(0.046**)   -0.430(0.075*)
# 1     氧化钠(Na2O)   -0.475(0.046**)  1.000(0.000***)    -0.113(0.656)
# 2      氧化铜(CuO)    -0.430(0.075*)    -0.113(0.656)  1.000(0.000***)
# 3     二氧化硫(SO2)     -0.284(0.253)    -0.198(0.431)     0.354(0.149)
# 4      氧化镁(MgO)   -0.546(0.019**)    -0.223(0.373)     0.204(0.417)
# 5     氧化锡(SnO2)      0.070(0.782)    -0.108(0.670)    -0.398(0.102)
# 6      氧化锶(SrO)   -0.524(0.026**)    -0.110(0.665)     0.141(0.577)
# 7      氧化钾(K2O)  -0.781(0.000***)  0.606(0.008***)     0.179(0.477)
# 8   五氧化二磷(P2O5)   -0.530(0.024**)    -0.221(0.378)    0.466(0.051*)
# 9      氧化钡(BaO)     -0.346(0.160)    -0.236(0.347)   0.483(0.042**)
# 10     氧化钙(CaO)  -0.752(0.000***)  0.640(0.004***)     0.344(0.162)
# 11     氧化铅(PbO)    -0.443(0.066*)     0.266(0.287)     0.047(0.853)
# 12   氧化铁(Fe2O3)  -0.783(0.000***)     0.218(0.385)  0.643(0.004***)
# 13   氧化铝(Al2O3)  -0.831(0.000***)     0.313(0.206)     0.246(0.326)
#
#          二氧化硫(SO2)         氧化镁(MgO)        氧化锡(SnO2)         氧化锶(SrO)   \
# 0     -0.284(0.253)  -0.546(0.019**)     0.070(0.782)  -0.524(0.026**)
# 1     -0.198(0.431)    -0.223(0.373)    -0.108(0.670)    -0.110(0.665)
# 2      0.354(0.149)     0.204(0.417)    -0.398(0.102)     0.141(0.577)
# 3   1.000(0.000***)    0.429(0.076*)    -0.108(0.670)    -0.023(0.929)
# 4     0.429(0.076*)  1.000(0.000***)     0.214(0.393)  0.666(0.003***)
# 5     -0.108(0.670)     0.214(0.393)  1.000(0.000***)     0.306(0.216)
# 6     -0.023(0.929)  0.666(0.003***)     0.306(0.216)  1.000(0.000***)
# 7      0.307(0.215)     0.256(0.305)     0.070(0.782)    0.404(0.096*)
# 8      0.246(0.324)  0.643(0.004***)     0.304(0.220)   0.500(0.035**)
# 9     -0.236(0.347)   0.521(0.027**)    -0.128(0.612)   0.565(0.015**)
# 10     0.389(0.110)     0.087(0.731)    -0.374(0.126)    -0.052(0.839)
# 11    -0.341(0.165)     0.295(0.234)    -0.186(0.460)     0.368(0.133)
# 12     0.313(0.206)   0.569(0.014**)    -0.374(0.126)    0.409(0.092*)
# 13     0.246(0.325)  0.735(0.001***)    -0.164(0.517)   0.511(0.030**)
#
#            氧化钾(K2O)      五氧化二磷(P2O5)         氧化钡(BaO)          氧化钙(CaO)   \
# 0   -0.781(0.000***)  -0.530(0.024**)    -0.346(0.160)  -0.752(0.000***)
# 1    0.606(0.008***)    -0.221(0.378)    -0.236(0.347)   0.640(0.004***)
# 2       0.179(0.477)    0.466(0.051*)   0.483(0.042**)      0.344(0.162)
# 3       0.307(0.215)     0.246(0.324)    -0.236(0.347)      0.389(0.110)
# 4       0.256(0.305)  0.643(0.004***)   0.521(0.027**)      0.087(0.731)
# 5       0.070(0.782)     0.304(0.220)    -0.128(0.612)     -0.374(0.126)
# 6      0.404(0.096*)   0.500(0.035**)   0.565(0.015**)     -0.052(0.839)
# 7    1.000(0.000***)     0.156(0.536)    -0.010(0.969)   0.690(0.002***)
# 8       0.156(0.536)  1.000(0.000***)   0.471(0.049**)      0.023(0.929)
# 9      -0.010(0.969)   0.471(0.049**)  1.000(0.000***)     -0.073(0.773)
# 10   0.690(0.002***)     0.023(0.929)    -0.073(0.773)   1.000(0.000***)
# 11      0.241(0.335)     0.121(0.633)  0.682(0.002***)      0.256(0.305)
# 12     0.457(0.056*)   0.517(0.028**)   0.539(0.021**)    0.537(0.022**)
# 13    0.506(0.032**)   0.518(0.028**)   0.473(0.047**)    0.521(0.026**)
#
#           氧化铅(PbO)        氧化铁(Fe2O3)        氧化铝(Al2O3)
# 0    -0.443(0.066*)  -0.783(0.000***)  -0.831(0.000***)
# 1      0.266(0.287)      0.218(0.385)      0.313(0.206)
# 2      0.047(0.853)   0.643(0.004***)      0.246(0.326)
# 3     -0.341(0.165)      0.313(0.206)      0.246(0.325)
# 4      0.295(0.234)    0.569(0.014**)   0.735(0.001***)
# 5     -0.186(0.460)     -0.374(0.126)     -0.164(0.517)
# 6      0.368(0.133)     0.409(0.092*)    0.511(0.030**)
# 7      0.241(0.335)     0.457(0.056*)    0.506(0.032**)
# 8      0.121(0.633)    0.517(0.028**)    0.518(0.028**)
# 9   0.682(0.002***)    0.539(0.021**)    0.473(0.047**)
# 10     0.256(0.305)    0.537(0.022**)    0.521(0.026**)
# 11  1.000(0.000***)      0.323(0.191)   0.602(0.008***)
# 12     0.323(0.191)   1.000(0.000***)   0.748(0.000***)
# 13  0.602(0.008***)   0.748(0.000***)   1.000(0.000***)

# %% [markdown]
# ## 下面是高钾

# %%
def is_number(s):   #函数功能-判断字符串是否为数字
    try:  # 如果能运行float(s)语句，返回True（字符串s是浮点数）
        float(s)
        return True
    except ValueError:  # ValueError为Python的一种标准异常，表示"传入无效的参数"
        pass  # 如果引发了ValueError这种异常，不做任何事情（pass：不做任何事情，一般用做占位语句）
    try:
        import unicodedata  # 处理ASCii码的包
        unicodedata.numeric(s)  # 把一个表示数字的字符串转换为浮点数返回的函数
        return True
    except (TypeError, ValueError):
        pass
    return False

高钾相关性 = np.array(高钾数据)
高钾相关性
高钾显著性检验值 = []
for it in 高钾相关性:
    temp = [it[0]]
    for it2 in it:
        左括号位置 = it2.find('(')
        右括号位置 = it2.find(')')
        #print(it2, (左括号位置, 右括号位置), end='')
        it2 = it2[左括号位置+1:右括号位置].strip('*')
        if is_number(it2):
            it2 = float(it2)
            temp.append(it2)
            #print(it2, end='')
        #print()
    高钾显著性检验值.append(temp)
高钾显著性检验值

# %%
#将P值符合条件的相关关系筛选出来
df = pd.DataFrame(高钾显著性检验值, columns=['名称','二氧化硅(SiO2)', '氧化钠(Na2O)', '氧化铜(CuO)', '二氧化硫(SO2)',  '氧化镁(MgO)', '氧化锡(SnO2)', '氧化锶(SrO)',	'氧化钾(K2O)', '五氧化二磷(P2O5)', '氧化钡(BaO)', '氧化钙(CaO)', '氧化铅(PbO)',	'氧化铁(Fe2O3)', '氧化铝(Al2O3)'])
df.to_csv('./高钾显著性检验值.csv', index=False)

有相关性的值 = []
index = ['名称','二氧化硅(SiO2)', '氧化钠(Na2O)', '氧化铜(CuO)', '二氧化硫(SO2)',  '氧化镁(MgO)', '氧化锡(SnO2)', '氧化锶(SrO)',	'氧化钾(K2O)', '五氧化二磷(P2O5)', '氧化钡(BaO)', '氧化钙(CaO)', '氧化铅(PbO)',	'氧化铁(Fe2O3)', '氧化铝(Al2O3)']
for i in range(len(高钾显著性检验值)):
    for j in range(1, i):
        if 高钾显著性检验值[i][j] < 0.05:
            #print(高钾显著性检验值[i][j], (i, j), end='')
            #print('对应的相关系数值=', end='')
            l = 高钾相关性[i][j].find('(')
            r = 高钾相关性[i][j].find(')')
            相关系数值 = float(高钾相关性[i][j][:l])
            #print(相关系数值, (index[i+1],index[j]))
            有相关性的值.append((相关系数值, (index[i+1],index[j])))

for i in range(len(有相关性的值)):
    for j in range(len(有相关性的值)-i-1):
        if 有相关性的值[j][0] > 有相关性的值[j+1][0]:
            temp = 有相关性的值[j]
            有相关性的值[j] = 有相关性的值[j+1]
            有相关性的值[j+1] = temp
print(有相关性的值, len(有相关性的值))
# Out:
# [(-0.831, ('氧化铝(Al2O3)', '二氧化硅(SiO2)')), (-0.783, ('氧化铁(Fe2O3)', '二氧化硅(SiO2)')), (-0.781, ('氧化钾(K2O)', '二氧化硅(SiO2)')), (-0.752, ('氧化钙(CaO)', '二氧化硅(SiO2)')), (-0.546, ('氧化镁(MgO)', '二氧化硅(SiO2)')), (-0.53, ('五氧化二磷(P2O5)', '二氧化硅(SiO2)')), (-0.524, ('氧化锶(SrO)', '二氧化硅(SiO2)')), (0.473, ('氧化铝(Al2O3)', '氧化钡(BaO)')), (0.483, ('氧化钡(BaO)', '氧化铜(CuO)')), (0.5, ('五氧化二磷(P2O5)', '氧化锶(SrO)')), (0.506, ('氧化铝(Al2O3)', '氧化钾(K2O)')), (0.511, ('氧化铝(Al2O3)', '氧化锶(SrO)')), (0.517, ('氧化铁(Fe2O3)', '五氧化二磷(P2O5)')), (0.518, ('氧化铝(Al2O3)', '五氧化二磷(P2O5)')), (0.521, ('氧化钡(BaO)', '氧化镁(MgO)')), (0.521, ('氧化铝(Al2O3)', '氧化钙(CaO)')), (0.537, ('氧化铁(Fe2O3)', '氧化钙(CaO)')), (0.539, ('氧化铁(Fe2O3)', '氧化钡(BaO)')), (0.565, ('氧化钡(BaO)', '氧化锶(SrO)')), (0.569, ('氧化铁(Fe2O3)', '氧化镁(MgO)')), (0.602, ('氧化铝(Al2O3)', '氧化铅(PbO)')), (0.606, ('氧化钾(K2O)', '氧化钠(Na2O)')), (0.64, ('氧化钙(CaO)', '氧化钠(Na2O)')), (0.643, ('五氧化二磷(P2O5)', '氧化镁(MgO)')), (0.643, ('氧化铁(Fe2O3)', '氧化铜(CuO)')), (0.666, ('氧化锶(SrO)', '氧化镁(MgO)')), (0.682, ('氧化铅(PbO)', '氧化钡(BaO)')), (0.69, ('氧化钙(CaO)', '氧化钾(K2O)')), (0.735, ('氧化铝(Al2O3)', '氧化镁(MgO)'))] 29

# %%
#对筛选出来的相关关系进行强度分类
#•	0.8-1.0 极强相关
#•	0.6-0.8 强相关
#•	0.4-0.6 中等程度相关
#•	0.2-0.4 弱相关
#•	0.0-0.2 极弱相关或无相关
极强相关 = []
强相关 = []
中等相关 = []
弱相关 = []

正相关 = []
负相关 = []
for it in 有相关性的值:
    if abs(it[0]) >= 0.8:
        极强相关.append(it)
    elif abs(it[0]) >= 0.6:
        强相关.append(it)
    elif abs(it[0]) >= 0.4:
        中等相关.append(it)
for it in 有相关性的值:
    if it[0] > 0 :
        正相关.append(it)
    elif it[0] < 0 : 
        负相关.append(it)
print(len(有相关性的值), len(极强相关), len(强相关), len(中等相关), len(正相关), len(负相关))

for i in 中等相关:
    print(i[1][0], '与', i[1][1], '相关系数=', i[0])
# for i in 强相关:
#     print(i[1][0], '与', i[1][1], '相关系数=', i[0])
# for i in 极强相关:
#     print(i[1][0], '与', i[1][1], '相关系数=', i[0])
# Out:
# 29 1 12 16 22 7
# 氧化镁(MgO) 与 二氧化硅(SiO2) 相关系数= -0.546
# 五氧化二磷(P2O5) 与 二氧化硅(SiO2) 相关系数= -0.53
# 氧化锶(SrO) 与 二氧化硅(SiO2) 相关系数= -0.524
# 氧化铝(Al2O3) 与 氧化钡(BaO) 相关系数= 0.473
# 氧化钡(BaO) 与 氧化铜(CuO) 相关系数= 0.483
# 五氧化二磷(P2O5) 与 氧化锶(SrO) 相关系数= 0.5
# 氧化铝(Al2O3) 与 氧化钾(K2O) 相关系数= 0.506
# 氧化铝(Al2O3) 与 氧化锶(SrO) 相关系数= 0.511
# 氧化铁(Fe2O3) 与 五氧化二磷(P2O5) 相关系数= 0.517
# 氧化铝(Al2O3) 与 五氧化二磷(P2O5) 相关系数= 0.518
# 氧化钡(BaO) 与 氧化镁(MgO) 相关系数= 0.521
# 氧化铝(Al2O3) 与 氧化钙(CaO) 相关系数= 0.521
# 氧化铁(Fe2O3) 与 氧化钙(CaO) 相关系数= 0.537
# 氧化铁(Fe2O3) 与 氧化钡(BaO) 相关系数= 0.539
# 氧化钡(BaO) 与 氧化锶(SrO) 相关系数= 0.565
# 氧化铁(Fe2O3) 与 氧化镁(MgO) 相关系数= 0.569

# %%
#相关强度分布图
import matplotlib.pyplot as plt
plt.rcParams["font.sans-serif"]=["SimHei"] #设置字体
plt.rcParams["axes.unicode_minus"]=False #该语句解决图像中的“-”负号的乱码问题
res = [len(极强相关), len(强相关), len(中等相关)]
res2 = [len(正相关), len(负相关)]

plt.pie(res,
    labels=['极强相关(' + str(len(极强相关)) + '个)', '强相关(' + str(len(强相关)) + '个)', '中等强度相关(' + str(len(中等相关)) + '个)'],
    autopct='%.2f%%') # 格式化输出百分比
plt.title('相关强度分布图')
plt.show()

plt.pie(res2,
    labels=['正相关(' + str(len(正相关)) + '个)', '负相关(' + str(len(负相关)) + '个)'],
    autopct='%.2f%%') # 格式化输出百分比
plt.title('相关强度分布图2')
plt.show()

# %% [markdown]
# ## 下面是铅钡

# %%
铅钡相关性 = np.array(铅钡数据)
铅钡相关性
铅钡显著性检验值 = []
for it in 铅钡相关性:
    temp = [it[0]]
    for it2 in it:
        左括号位置 = it2.find('(')
        右括号位置 = it2.find(')')
        #print(it2, (左括号位置, 右括号位置), end='')
        it2 = it2[左括号位置+1:右括号位置].strip('*')
        if is_number(it2):
            it2 = float(it2)
            temp.append(it2)
            #print(it2, end='')
        #print()
    铅钡显著性检验值.append(temp)
铅钡显著性检验值

# %%
df = pd.DataFrame(铅钡显著性检验值, columns=['名称','二氧化硅(SiO2)', '氧化钠(Na2O)', '氧化铜(CuO)', '二氧化硫(SO2)',  '氧化镁(MgO)', '氧化锡(SnO2)', '氧化锶(SrO)',	'氧化钾(K2O)', '五氧化二磷(P2O5)', '氧化钡(BaO)', '氧化钙(CaO)', '氧化铅(PbO)',	'氧化铁(Fe2O3)', '氧化铝(Al2O3)'])
df.to_csv('./铅钡显著性检验值.csv', index=False)

有相关性的值2 = []
index = ['名称','二氧化硅(SiO2)', '氧化钠(Na2O)', '氧化铜(CuO)', '二氧化硫(SO2)',  '氧化镁(MgO)', '氧化锡(SnO2)', '氧化锶(SrO)',	'氧化钾(K2O)', '五氧化二磷(P2O5)', '氧化钡(BaO)', '氧化钙(CaO)', '氧化铅(PbO)',	'氧化铁(Fe2O3)', '氧化铝(Al2O3)']
for i in range(len(铅钡显著性检验值)):
    for j in range(1, i):
        if 铅钡显著性检验值[i][j] < 0.05:
            #print(铅钡显著性检验值[i][j], (i, j), end='')
            #print('对应的相关系数值=', end='')
            l = 铅钡相关性[i][j].find('(')
            r = 铅钡相关性[i][j].find(')')
            相关系数值 = float(铅钡相关性[i][j][:l])
            #print(相关系数值, (index[i+1],index[j]))
            有相关性的值2.append((相关系数值, (index[i+1],index[j])))

for i in range(len(有相关性的值2)):
    for j in range(len(有相关性的值2)-i-1):
        if 有相关性的值2[j][0] > 有相关性的值2[j+1][0]:
            temp = 有相关性的值2[j]
            有相关性的值2[j] = 有相关性的值2[j+1]
            有相关性的值2[j+1] = temp
print(有相关性的值2, len(有相关性的值2))
# Out:
# [(-0.757, ('氧化铅(PbO)', '二氧化硅(SiO2)')), (-0.57, ('氧化钡(BaO)', '氧化钠(Na2O)')), (-0.552, ('氧化锶(SrO)', '二氧化硅(SiO2)')), (-0.538, ('氧化钡(BaO)', '二氧化硅(SiO2)')), (-0.49, ('五氧化二磷(P2O5)', '二氧化硅(SiO2)')), (-0.447, ('氧化铝(Al2O3)', '二氧化硅(SiO2)')), (-0.443, ('氧化铁(Fe2O3)', '氧化镁(MgO)')), (-0.435, ('氧化镁(MgO)', '氧化铜(CuO)')), (-0.385, ('氧化钙(CaO)', '氧化锡(SnO2)')), (-0.369, ('氧化钙(CaO)', '氧化镁(MgO)')), (-0.368, ('氧化锡(SnO2)', '氧化铜(CuO)')), (-0.367, ('五氧化二磷(P2O5)', '氧化钠(Na2O)')), (-0.357, ('氧化铅(PbO)', '氧化钠(Na2O)')), (-0.356, ('氧化铝(Al2O3)', '氧化钾(K2O)')), (-0.337, ('氧化铁(Fe2O3)', '氧化锡(SnO2)')), (-0.336, ('氧化铅(PbO)', '二氧化硫(SO2)')), (-0.325, ('氧化铝(Al2O3)', '氧化钙(CaO)')), (-0.313, ('氧化锡(SnO2)', '二氧化硅(SiO2)')), (0.308, ('二氧化硫(SO2)', '二氧化硅(SiO2)')), (0.308, ('五氧化二磷(P2O5)', '氧化锶(SrO)')), (0.325, ('五氧化二磷(P2O5)', '氧化铜(CuO)')), (0.333, ('氧化钙(CaO)', '氧化钾(K2O)')), (0.351, ('氧化铅(PbO)', '五氧化二磷(P2O5)')), (0.361, ('氧化铅(PbO)', '氧化钡(BaO)')), (0.362, ('氧化铅(PbO)', '氧化锶(SrO)')), (0.363, ('氧化铁(Fe2O3)', '氧化钾(K2O)')), (0.387, ('氧化铁(Fe2O3)', '氧化钙(CaO)')), (0.411, ('氧化铁(Fe2O3)', '五氧化二磷(P2O5)')), (0.425, ('氧化钙(CaO)', '二氧化硅(SiO2)')), (0.449, ('氧化铝(Al2O3)', '氧化锡(SnO2)')), (0.495, ('氧化铝(Al2O3)', '氧化镁(MgO)')), (0.512, ('氧化钙(CaO)', '二氧化硫(SO2)')), (0.674, ('氧化钙(CaO)', '氧化铜(CuO)'))] 33

# %%
#对筛选出来的相关关系进行强度分类
#•	0.8-1.0 极强相关
#•	0.6-0.8 强相关
#•	0.4-0.6 中等程度相关
#•	0.2-0.4 弱相关
#•	0.0-0.2 极弱相关或无相关
极强相关 = []
强相关 = []
中等相关 = []
弱相关 = []
正相关 = []
负相关 = []

for it in 有相关性的值2:
    if abs(it[0]) >= 0.8:
        极强相关.append(it)
    elif abs(it[0]) >= 0.6:
        强相关.append(it)
    elif abs(it[0]) >= 0.4:
        中等相关.append(it)
    else:
        弱相关.append(it)
for it in 有相关性的值2:
    if it[0] > 0 :
        正相关.append(it)
    elif it[0] < 0 : 
        负相关.append(it)
print(len(有相关性的值2), len(极强相关), len(强相关), len(中等相关), len(弱相关), len(正相关), len(负相关))
# for i in 中等相关:
#     print(i[1][0], '与', i[1][1], '相关系数=', i[0])
# for i in 弱相关:
#     print(i[1][0], '与', i[1][1], '相关系数=', i[0])
# for i in 强相关:
#     print(i[1][0], '与', i[1][1], '相关系数=', i[0])
# Out:
# 33 0 2 12 19 15 18
# 氧化铅(PbO) 与 二氧化硅(SiO2) 相关系数= -0.757
# 氧化钙(CaO) 与 氧化铜(CuO) 相关系数= 0.674

# %%
#相关强度分布图
import matplotlib.pyplot as plt
plt.rcParams["font.sans-serif"]=["SimHei"] #设置字体
plt.rcParams["axes.unicode_minus"]=False #该语句解决图像中的“-”负号的乱码问题
res = [len(强相关), len(中等相关), len(弱相关)]
res2 = [len(正相关), len(负相关)]

plt.pie(res,
    labels=['强相关(' + str(len(强相关)) + '个)', '中等强度相关(' + str(len(中等相关)) + '个)', '弱相关(' + str(len(弱相关)) + '个)'],
    autopct='%.2f%%') # 格式化输出百分比
plt.title('相关强度分布图')
plt.show()

plt.pie(res2,
    labels=['正相关(' + str(len(正相关)) + '个)', '负相关(' + str(len(负相关)) + '个)'],
    autopct='%.2f%%') # 格式化输出百分比
plt.title('相关强度分布图2')
plt.show()
